# %%
import yfinance as yf
dat = yf.Ticker("MSFT")

# %%
dat = yf.Ticker("MSFT")
dat.info
dat.calendar
dat.analyst_price_targets
dat.quarterly_income_stmt
dat.history(period='1mo')
dat.option_chain(dat.options[0]).calls
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0    MSFT250620C00115000 2025-06-12 19:13:22+00:00   115.0     364.74    0.0
# 1    MSFT250620C00120000 2025-05-27 19:55:01+00:00   120.0     340.65    0.0
# 2    MSFT250620C00125000 2025-05-14 18:38:38+00:00   125.0     326.80  348.0
# 3    MSFT250620C00130000 2025-06-11 19:19:28+00:00   130.0     342.00    0.0
# 4    MSFT250620C00135000 2025-06-12 19:46:50+00:00   135.0     343.85    0.0
# ..                   ...                       ...     ...        ...    ...
# 133  MSFT250620C00680000 2025-05-16 13:33:26+00:00   680.0       0.01    0.0
# 134  MSFT250620C00685000 2025-02-05 20:55:45+00:00   685.0       0.08    0.0
# 135  MSFT250620C00690000 2025-02-20 19:24:16+00:00   690.0       0.03    0.0
# 136  MSFT250620C00695000 2025-05-05 16:23:12+00:00   695.0       0.02    0.0
# 137  MSFT250620C00700000 2025-06-16 15:45:57+00:00   700.0       0.01    0.0
#
#         ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0      0.00     0.0            0.0     2.0             0           0.000010
# 1      0.00     0.0            0.0     1.0             0           0.000010
# 2    351.15     0.0            0.0   185.0             0           0.000010
# 3      0.00     0.0            0.0    25.0             0           0.000010
# 4      0.00     0.0            0.0     2.0             0           0.000010
# ..      ...     ...            ...     ...           ...                ...
# 133    0.00     0.0            0.0     8.0             0           0.500005
# 134    0.58     0.0            0.0     3.0            23           1.462893
# 135    0.01     0.0            0.0     1.0            36           1.031255
# 136    0.01     0.0            0.0     4.0            92           1.031255
# 137    0.00     0.0            0.0    10.0             0           0.500005
#
#      inTheMoney contractSize currency
# 0          True      REGULAR      USD
# 1          True      REGULAR      USD
# 2          True      REGULAR      USD
# 3          True      REGULAR      USD
# 4          True      REGULAR      USD
# ..          ...          ...      ...
# 133       False      REGULAR      USD
# 134       False      REGULAR      USD
# 135       False      REGULAR      USD
# 136       False      REGULAR      USD
# 137       False      REGULAR      USD
#
# [138 rows x 14 columns]

# %%
# get list of quotes
quotes = yf.Search("AAPL", max_results=10).quotes

# get list of news
news = yf.Search("Google", news_count=10).news

# get list of related research
research = yf.Search("apple", include_research=True).research

# %%
news
# Out:
# [{'uuid': '5963f8cd-69b1-3e15-b281-dd03f46bed28',
#   'title': 'Google to scale up AI-powered fraud detection and security operations in India',
#   'publisher': 'TechCrunch',
#   'link': 'https://finance.yahoo.com/news/google-scale-ai-powered-fraud-070100010.html',
#   'providerPublishTime': 1750143660,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/XzM8TKy7z6laBf0Jdn0nzA--~B/aD0zMzMzO3c9NTAwMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/techcrunch_finance_785/c07e73a395558cb31a987a57f7756d8f',
#      'width': 5000,
#      'height': 3333,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/AAFX1yULRsNe63znBZTVSw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/techcrunch_finance_785/c07e73a395558cb31a987a57f7756d8f',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['GOOG']},
#  {'uuid': 'b496736c-02a8-3ed9-af3b-857342157a27',
#   'title': 'Google plans major AI shift after Meta’s surprising $14 billion move',
#   'publisher': 'TheStreet',
#   'link': 'https://finance.yahoo.com/m/b496736c-02a8-3ed9-af3b-857342157a27/google-plans-major-ai-shift.html',
#   'providerPublishTime': 1750127580,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/3GCTG.a2DRP_jj1QROIb0A--~B/aD02NzU7dz0xMjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/thestreet_881/8585edea094267bf6d51d67a1242d5ec',
#      'width': 1200,
#      'height': 675,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/OdOCyaLSI0nU3Ow4oyksfQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/thestreet_881/8585edea094267bf6d51d67a1242d5ec',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['GOOG', 'META']},
#  {'uuid': '6468f333-ca47-3ea3-a732-3706b8e0a21b',
#   'title': 'Entangled Networks Market Research Report 2026-2040 Featuring Tech Giants Such as IBM and Google, Alongside Specialized Startups like IonQ and Qunnect',
#   'publisher': 'GlobeNewswire',
#   'link': 'https://finance.yahoo.com/news/entangled-networks-market-research-report-080800647.html',
#   'providerPublishTime': 1750147680,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/HP.E8HUfnyGeLtMAKwLgAQ--~B/aD01ODt3PTQ4MDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/globenewswire.com/93d5b27580f67db722dd7c112e43e8bc',
#      'width': 480,
#      'height': 58,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/KPtVInxraKsLNBMRw1U5aw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/93d5b27580f67db722dd7c112e43e8bc',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': '4afc1ba1-6868-30ad-893e-f459cc4f55f3',
#   'title': 'Google to terminate Scale AI partnership',
#   'publisher': 'Verdict',
#   'link': 'https://finance.yahoo.com/m/4afc1ba1-6868-30ad-893e-f459cc4f55f3/google-to-terminate-scale-ai.html',
#   'providerPublishTime': 1750071586,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/tk_Wrbn3PHVW_n6I9JQO9g--~B/aD04MTA7dz0xNDQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/verdict_626/c886f7331da6cb03cb7b06f2a382636f',
#      'width': 1440,
#      'height': 810,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/BF7SznzREHJwTCSQC7fOEw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/verdict_626/c886f7331da6cb03cb7b06f2a382636f',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['GOOG']},
#  {'uuid': '16e377a0-8c6e-3aab-ad22-5fc2153f18fb',
#   'title': 'Google (GOOGL) Resolves Global Outage That Disrupted Gmail, Cloud, and Partner Apps',
#   'publisher': 'GuruFocus.com',
#   'link': 'https://finance.yahoo.com/m/16e377a0-8c6e-3aab-ad22-5fc2153f18fb/google-%28googl%29-resolves.html',
#   'providerPublishTime': 1750077142,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/aakGjSnlAyqMHIQspghQdg--~B/aD0zNjY7dz01NTA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/us.finance.gurufocus/37e4fd10a425775da0ea511eac1f520d',
#      'width': 550,
#      'height': 366,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/fWjFvfNSlHGw1qAakMnYIw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/us.finance.gurufocus/37e4fd10a425775da0ea511eac1f520d',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['GOOG']},
#  {'uuid': '59238ff7-4f6b-3c92-a9b9-c307a8a97e72',
#   'title': 'Google Cleared by Mexico Regulator of Antitrust Charges in Advertisement Sales',
#   'publisher': 'MT Newswires',
#   'link': 'https://finance.yahoo.com/news/google-cleared-mexico-regulator-antitrust-102627147.html',
#   'providerPublishTime': 1750069587,
#   'type': 'STORY',
#   'relatedTickers': ['GOOG']},
#  {'uuid': 'cb795a90-8e24-3059-a9d7-c10d93861702',
#   'title': "Oracle Stock Pops as Company Shows It Is Catching Up in the Cloud Race. Here's What That Means for Investors",
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/cb795a90-8e24-3059-a9d7-c10d93861702/oracle-stock-pops-as-company.html',
#   'providerPublishTime': 1750147200,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/TQjSeh_0w.zwVklaaRLp6g--~B/aD05MzM7dz0xNDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/6bc32bec2e261d37df3ecb1d8a346779',
#      'width': 1400,
#      'height': 933,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/BYQfeFdI_pHF1xdLnj8RPA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/6bc32bec2e261d37df3ecb1d8a346779',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['ORCL', 'MSFT', 'AMZN', 'GOOG']},
#  {'uuid': 'b17e1d65-7caf-38eb-9b36-1644ddb5e33c',
#   'title': 'Update: Market Chatter: Google to Cut Ties With Scale AI After Meta Platforms Deal',
#   'publisher': 'MT Newswires',
#   'link': 'https://finance.yahoo.com/news/market-chatter-google-cut-ties-154233462.html',
#   'providerPublishTime': 1750088553,
#   'type': 'STORY',
#   'relatedTickers': ['GOOG', 'MSFT']},
#  {'uuid': '5b2dd380-a732-3526-a6f1-b88ffb31c5b1',
#   'title': 'Meta Just Spent $14.8B on AI--and Triggered a Big Tech Breakup',
#   'publisher': 'GuruFocus.com',
#   'link': 'https://finance.yahoo.com/news/meta-just-spent-14-8b-190639986.html',
#   'providerPublishTime': 1750100799,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/l4RQ9ctGoVJ.pATDH._65Q--~B/aD0xOTIwO3c9MTkyMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/us.finance.gurufocus/0a1fabbe0615fb9205b4c17d7c6011e3',
#      'width': 1920,
#      'height': 1920,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/VUt4xocHBmNOSFpKPnmsyA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/us.finance.gurufocus/0a1fabbe0615fb9205b4c17d7c6011e3',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['META']},
#  {'uuid': 'e35f9cc6-5b12-3c7c-a90b-ee601e8799dc',
#   'title': 'Ericsson, Google Cloud Launch AI-Powered 5G Core Network as-a-Service',
#   'publisher': 'Zacks',
#   'link': 'https://finance.yahoo.com/news/ericsson-google-cloud-launch-ai-134700908.html',
#   'providerPublishTime': 1750081620,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/ZC8OyWBw5yTSm60pOxYbCQ--~B/aD00MTM7dz02MjA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/zacks.com/ee890f2c97d802ce33d12d0ecb9fcf51',
#      'width': 620,
#      'height': 413,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/JIibT.GjQIljGmsCymgCtQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/zacks.com/ee890f2c97d802ce33d12d0ecb9fcf51',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['ERIC', 'JNPR']}]

# %%
research
# Out:
# [{'reportHeadline': 'Analyst Report: Apple Inc.',
#   'author': 'William Kerwin',
#   'reportDate': 1749498367000,
#   'id': 'MS_0P000000GY_AnalystReport_1749498367000',
#   'provider': 'Morningstar'},
#  {'reportHeadline': 'The Argus Sustainable Growth Theme Model Portfolio',
#   'author': 'John Eade',
#   'reportDate': 1748524165000,
#   'id': 'ARGUS_43667_ThematicPortfolio_1748524165000',
#   'provider': 'Argus'},
#  {'reportHeadline': 'Morningstar | A Weekly Summary of Stock Ideas and Developments in the Companies We Cover',
#   'reportDate': 1748042102000,
#   'id': 'MS_1286187_StockPicks_1748042102000',
#   'provider': 'Morningstar'}]

# %%
import asyncio
import yfinance as yf

# define your message callback
def message_handler(message):
    print("Received message:", message)

async def main():
    # =======================
    # With Context Manager
    # =======================
    async with yf.AsyncWebSocket() as ws:
        await ws.subscribe(["AAPL", "BTC-USD"])
        await ws.listen()

    # =======================
    # Without Context Manager
    # =======================
    ws = yf.AsyncWebSocket()
    await ws.subscribe(["AAPL", "BTC-USD"])
    await ws.listen()

asyncio.run(main())
# Out:
# Connected to WebSocket.
# Subscribed to symbols: ['AAPL', 'BTC-USD']
# Listening for messages...
# Heartbeat subscription sent for symbols: {'AAPL', 'BTC-USD'}
# Heartbeat subscription sent for symbols: {'AAPL', 'BTC-USD'}
# Heartbeat subscription sent for symbols: {'AAPL', 'BTC-USD'}
# {'id': 'BTC-USD', 'price': 106264.39, 'time': '1750153380000', 'currency': 'USD', 'exchange': 'CCC', 'quote_type': 41, 'market_hours': 1, 'change_percent': -0.67477703, 'day_volume': '52835233792', 'day_high': 107682.805, 'day_low': 106264.39, 'change': -721.9219, 'open_price': 106798.67, 'last_size': '52835233792', 'price_hint': '2', 'vol_24hr': '52835233792', 'vol_all_currencies': '52835233792', 'from_currency': 'BTC', 'circulating_supply': 19878000.0, 'market_cap': 2112323580000.0}
# {'id': 'AAPL', 'price': 197.42, 'time': '1750153470000', 'exchange': 'NMS', 'quote_type': 8, 'change_percent': -0.5039815, 'change': -1.0, 'price_hint': '2'}
# {'id': 'BTC-USD', 'price': 106264.39, 'time': '1750153380000', 'currency': 'USD', 'exchange': 'CCC', 'quote_type': 41, 'market_hours': 1, 'change_percent': -0.67477703, 'day_volume': '52835233792', 'day_high': 107682.805, 'day_low': 106264.39, 'change': -721.9219, 'open_price': 106798.67, 'last_size': '52835233792', 'price_hint': '2', 'vol_24hr': '52835233792', 'vol_all_currencies': '52835233792', 'from_currency': 'BTC', 'circulating_supply': 19878000.0, 'market_cap': 2112323580000.0}
# {'id': 'AAPL', 'price': 197.43, 'time': '1750153474000', 'exchange': 'NMS', 'quote_type': 8, 'change_percent': -0.4989444, 'change': -0.9900055, 'price_hint': '2'}
# {'id': 'AAPL', 'price': 197.43, 'time': '1750153478000', 'exchange': 'NMS', 'quote_type': 8, 'change_percent': -0.4989444, 'change': -0.9900055, 'price_hint': '2'}
# {'id': 'AAPL', 'price': 197.43, 'time': '1750153481000', 'exchange': 'NMS', 'quote_type': 8, 'change_percent': -0.4989444, 'change': -0.9900055, 'price_hint': '2'}
# Heartbeat subscription sent for symbols: {'AAPL', 'BTC-USD'}
# {'id': 'AAPL', 'price': 197.44, 'time': '1750153496000', 'exchange': 'NMS', 'quote_type': 8, 'change_percent': -0.49389967, 'change': -0.9799957, 'price_hint': '2'}
# Heartbeat subscription sent for symbols: {'AAPL', 'BTC-USD'}
# {'id': 'AAPL', 'price': 197.39, 'time': '1750153499000', 'exchange': 'NMS', 'quote_type': 8, 'change_percent': -0.5191003, 'change': -1.0299988, 'price_hint': '2'}
# Heartbeat subscription sent for symbols: {'AAPL', 'BTC-USD'}
# Heartbeat subscription sent for symbols: {'AAPL', 'BTC-USD'}
# {'id': 'BTC-USD', 'price': 106253.14, 'time': '1750153440000', 'currency': 'USD', 'exchange': 'CCC', 'quote_type': 41, 'market_hours': 1, 'change_percent': -0.71505517, 'day_volume': '51752886272', 'day_high': 107682.805, 'day_low': 106253.14, 'change': -765.2344, 'open_price': 106798.67, 'last_size': '51752886272', 'price_hint': '2', 'vol_24hr': '51752886272', 'vol_all_currencies': '51752886272', 'from_currency': 'BTC', 'circulating_supply': 19878000.0, 'market_cap': 2112099980000.0}
# Heartbeat subscription sent for symbols: {'AAPL', 'BTC-USD'}
# {'id': 'AAPL', 'price': 197.39, 'time': '1750153546000', 'exchange': 'NMS', 'quote_type': 8, 'change_percent': -0.5191003, 'change': -1.0299988, 'price_hint': '2'}
# WebSocket listening interrupted. Closing connection...
# WebSocket connection closed.
# WebSocket connection closed.
# Connected to WebSocket.
# Subscribed to symbols: ['AAPL', 'BTC-USD']
# Listening for messages...
# Heartbeat subscription sent for symbols: {'AAPL', 'BTC-USD'}
# {'id': 'AAPL', 'price': 197.39, 'time': '1750153564000', 'exchange': 'NMS', 'quote_type': 8, 'change_percent': -0.5191003, 'change': -1.0299988, 'price_hint': '2'}

# %%
dat = yf.Ticker("MSFT")
dat.info
dat.calendar
dat.analyst_price_targets
dat.quarterly_income_stmt
dat.history(period='1mo')
dat.option_chain(dat.options[0]).calls
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    MSFT250620C00115000 2025-06-12 19:13:22+00:00   115.0     364.74  361.45
# 1    MSFT250620C00120000 2025-05-27 19:55:01+00:00   120.0     340.65  356.45
# 2    MSFT250620C00125000 2025-05-14 18:38:38+00:00   125.0     326.80  348.00
# 3    MSFT250620C00130000 2025-06-11 19:19:28+00:00   130.0     342.00  347.35
# 4    MSFT250620C00135000 2025-06-12 19:46:50+00:00   135.0     343.85  342.60
# ..                   ...                       ...     ...        ...     ...
# 133  MSFT250620C00680000 2025-05-16 13:33:26+00:00   680.0       0.01    0.00
# 134  MSFT250620C00685000 2025-02-05 20:55:45+00:00   685.0       0.08    0.00
# 135  MSFT250620C00690000 2025-02-20 19:24:16+00:00   690.0       0.03    0.00
# 136  MSFT250620C00695000 2025-05-05 16:23:12+00:00   695.0       0.02    0.00
# 137  MSFT250620C00700000 2025-06-16 15:45:57+00:00   700.0       0.01    0.00
#
#         ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0    364.75     0.0            0.0     2.0            15           6.380861
# 1    359.60     0.0            0.0     1.0             5           6.117190
# 2    351.15     0.0            0.0   185.0             0           0.000010
# 3    349.90     0.0            0.0    25.0           373           6.281252
# 4    344.40     0.0            0.0     2.0           104           6.017581
# ..      ...     ...            ...     ...           ...                ...
# 133    0.01     0.0            0.0     8.0           312           0.984375
# 134    0.58     0.0            0.0     3.0            23           1.477542
# 135    0.01     0.0            0.0     1.0            36           1.031255
# 136    0.01     0.0            0.0     4.0            92           1.062505
# 137    0.01     0.0            0.0    10.0          2379           1.062505
#
#      inTheMoney contractSize currency
# 0          True      REGULAR      USD
# 1          True      REGULAR      USD
# 2          True      REGULAR      USD
# 3          True      REGULAR      USD
# 4          True      REGULAR      USD
# ..          ...          ...      ...
# 133       False      REGULAR      USD
# 134       False      REGULAR      USD
# 135       False      REGULAR      USD
# 136       False      REGULAR      USD
# 137       False      REGULAR      USD
#
# [138 rows x 14 columns]
